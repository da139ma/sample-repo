# %% [markdown]
# # Pandas

# %% [markdown]
# ### データセットを確認する
# - ファイルの入出力
# - head, tail
# - info, describe
# - columns, index
# - dtypes, shape

# %%
with open("./data/bank-names.txt", encoding="UTF-8") as f:
    print(f.read())
# Out:
# Citation Request:
#   This dataset is public available for research. The details are described in [Moro et al., 2011].
#   Please include this citation if you plan to use this database:
#
#   [Moro et al., 2011] S. Moro, R. Laureano and P. Cortez. Using Data Mining for Bank Direct Marketing: An Application of the CRISP-DM Methodology.
#   In P. Novais et al. (Eds.), Proceedings of the European Simulation and Modelling Conference - ESM'2011, pp. 117-121, Guimarães, Portugal, October, 2011. EUROSIS.
#
#   Available at: [pdf] http://hdl.handle.net/1822/14838
#                 [bib] http://www3.dsi.uminho.pt/pcortez/bib/2011-esm-1.txt
#
# 1. Title: Bank Marketing
#
# 2. Sources
#    Created by: Paulo Cortez (Univ. Minho) and Sérgio Moro (ISCTE-IUL) @ 2012
#
# 3. Past Usage:
#
#   The full dataset was described and analyzed in:
#
#   S. Moro, R. Laureano and P. Cortez. Using Data Mining for Bank Direct Marketing: An Application of the CRISP-DM Methodology.
#   In P. Novais et al. (Eds.), Proceedings of the European Simulation and Modelling Conference - ESM'2011, pp. 117-121, Guimarães,
#   Portugal, October, 2011. EUROSIS.
#
# 4. Relevant Information:
#
#    The data is related with direct marketing campaigns of a Portuguese banking institution.
#    The marketing campaigns were based on phone calls. Often, more than one contact to the same client was required,
#    in order to access if the product (bank term deposit) would be (or not) subscribed.
#
#    There are two datasets:
#       1) bank-full.csv with all examples, ordered by date (from May 2008 to November 2010).
#       2) bank.csv with 10% of the examples (4521), randomly selected from bank-full.csv.
#    The smallest dataset is provided to test more computationally demanding machine learning algorithms (e.g. SVM).
#
#    The classification goal is to predict if the client will subscribe a term deposit (variable y).
#
# 5. Number of Instances: 45211 for bank-full.csv (4521 for bank.csv)
#
# 6. Number of Attributes: 16 + output attribute.
#
# 7. Attribute information:
#
#    For more information, read [Moro et al., 2011].
#
#    Input variables:
#    # bank client data:
#    1 - age (numeric)
#    2 - job : type of job (categorical: "admin.","unknown","unemployed","management","housemaid","entrepreneur","student",
#                                        "blue-collar","self-employed","retired","technician","services")
#    3 - marital : marital status (categorical: "married","divorced","single"; note: "divorced" means divorced or widowed)
#    4 - education (categorical: "unknown","secondary","primary","tertiary")
#    5 - default: has credit in default? (binary: "yes","no")
#    6 - balance: average yearly balance, in euros (numeric)
#    7 - housing: has housing loan? (binary: "yes","no")
#    8 - loan: has personal loan? (binary: "yes","no")
#    # related with the last contact of the current campaign:
#    9 - contact: contact communication type (categorical: "unknown","telephone","cellular")
#   10 - day: last contact day of the month (numeric)
#   11 - month: last contact month of year (categorical: "jan", "feb", "mar", ..., "nov", "dec")
#   12 - duration: last contact duration, in seconds (numeric)
#    # other attributes:
#   13 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
#   14 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric, -1 means client was not previously contacted)
#   15 - previous: number of contacts performed before this campaign and for this client (numeric)
#   16 - poutcome: outcome of the previous marketing campaign (categorical: "unknown","other","failure","success")
#
#   Output variable (desired target):
#   17 - y - has the client subscribed a term deposit? (binary: "yes","no")
#
# 8. Missing Attribute Values: None

# %%
import pandas as pd

# %%
pip -v
# Out:
# Usage:
#   C:\Users\MIA17040\.conda\envs\openCV\python.exe -m pip <command> [options]
#
# Commands:
#   install                     Install packages.
#   download                    Download packages.
#   uninstall                   Uninstall packages.
#   freeze                      Output installed packages in requirements format.
#   list                        List installed packages.
#   show                        Show information about installed packages.
#   check                       Verify installed packages have compatible dependencies.
#   config                      Manage local and global configuration.
#   search                      Search PyPI for packages.
#   wheel                       Build wheels from your requirements.
#   hash                        Compute hashes of package archives.
#   completion                  A helper command used for command completion.
#   debug                       Show information useful for debugging.
#   help                        Show help for commands.
#
# General Options:
#   -h, --help                  Show help.
#   --isolated                  Run pip in an isolated mode, ignoring
#                               environment variables and user configuration.
#   -v, --verbose               Give more output. Option is additive, and can be
#                               used up to 3 times.
#   -V, --version               Show version and exit.
#   -q, --quiet                 Give less output. Option is additive, and can be
#                               used up to 3 times (corresponding to WARNING,
#                               ERROR, and CRITICAL logging levels).
#   --log <path>                Path to a verbose appending log.
#   --proxy <proxy>             Specify a proxy in the form
#                               [user:passwd@]proxy.server:port.
#   --retries <retries>         Maximum number of retries each connection should
#                               attempt (default 5 times).
#   --timeout <sec>             Set the socket timeout (default 15 seconds).
#   --exists-action <action>    Default action when a path already exists:
#                               (s)witch, (i)gnore, (w)ipe, (b)ackup, (a)bort.
#   --trusted-host <hostname>   Mark this host or host:port pair as trusted,
#                               even though it does not have valid or any HTTPS.
#   --cert <path>               Path to alternate CA bundle.
#   --client-cert <path>        Path to SSL client certificate, a single file
#                               containing the private key and the certificate
#                               in PEM format.
#   --cache-dir <dir>           Store the cache data in <dir>.
#   --no-cache-dir              Disable the cache.
#   --disable-pip-version-check
#                               Don't periodically check PyPI to determine
#                               whether a new version of pip is available for
#                               download. Implied with --no-index.
#   --no-color                  Suppress colored output
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\mia17040\.conda\envs\opencv\lib\site-packages (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\mia17040\.conda\envs\opencv\lib\site-packages (from pandas) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\mia17040\.conda\envs\opencv\lib\site-packages (from pandas) (2019.3)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\mia17040\.conda\envs\opencv\lib\site-packages (from pandas) (1.16.5)
# Requirement already satisfied: six>=1.5 in c:\users\mia17040\.conda\envs\opencv\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# 外部ファイルを読み込む
df = pd.read_csv("./data/bank.csv", sep=";")

# %%
# 外部ファイルに吐き出す
df.to_csv("./data/bank_output_test1.csv")
df.to_csv("./data/bank_output_test2.csv", index=False)
df.to_csv("./data/bank_output_test3.csv", index=False, sep=";")

# %%
# 上から5行を表示
df.head()
# Out:
#     age          job  marital  education default  balance housing loan  \
# 0  30.0   unemployed  married    primary      no     1787      no   no
# 1   NaN     services  married  secondary      no     4789     yes  yes
# 2  35.0   management   single   tertiary      no     1350     yes   no
# 3  30.0   management  married   tertiary      no     1476     yes  yes
# 4  59.0  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
# 下から指定行数を表示
df.tail(10)
# Out:
#        age            job  marital  education default  balance housing loan  \
# 4511  46.0    blue-collar  married  secondary      no      668     yes   no
# 4512  40.0    blue-collar  married  secondary      no     1100     yes   no
# 4513  49.0    blue-collar  married  secondary      no      322      no   no
# 4514  38.0    blue-collar  married  secondary      no     1205     yes   no
# 4515  32.0       services   single  secondary      no      473     yes   no
# 4516  33.0       services  married  secondary      no     -333     yes   no
# 4517  57.0  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518  57.0     technician  married  secondary      no      295      no   no
# 4519  28.0    blue-collar  married  secondary      no     1137      no   no
# 4520  44.0   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# 4511   unknown   15   may      1263         2     -1         0  unknown  yes
# 4512   unknown   29   may       660         2     -1         0  unknown   no
# 4513  cellular   14   aug       356         2     -1         0  unknown   no
# 4514  cellular   20   apr        45         4    153         1  failure   no
# 4515  cellular    7   jul       624         5     -1         0  unknown   no
# 4516  cellular   30   jul       329         5     -1         0  unknown   no
# 4517   unknown    9   may       153         1     -1         0  unknown   no
# 4518  cellular   19   aug       151        11     -1         0  unknown   no
# 4519  cellular    6   feb       129         4    211         3    other   no
# 4520  cellular    3   apr       345         2    249         7    other   no

# %%
df
# Out:
#        age            job  marital  education default  balance housing loan  \
# 0     30.0     unemployed  married    primary      no     1787      no   no
# 1      NaN       services  married  secondary      no     4789     yes  yes
# 2     35.0     management   single   tertiary      no     1350     yes   no
# 3     30.0     management  married   tertiary      no     1476     yes  yes
# 4     59.0    blue-collar  married  secondary      no        0     yes   no
# ...    ...            ...      ...        ...     ...      ...     ...  ...
# 4516  33.0       services  married  secondary      no     -333     yes   no
# 4517  57.0  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518  57.0     technician  married  secondary      no      295      no   no
# 4519  28.0    blue-collar  married  secondary      no     1137      no   no
# 4520  44.0   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 0     cellular   19   oct        79         1     -1         0  unknown  no
# 1     cellular   11   may       220         1    339         4  failure  no
# 2     cellular   16   apr       185         1    330         1  failure  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no
#
# [4521 rows x 17 columns]

# %%
# データフレームの情報を表示
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 1 to 6
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4 non-null      float64
#  1   job        5 non-null      object
#  2   marital    5 non-null      object
#  3   education  5 non-null      object
#  4   default    5 non-null      object
#  5   new_col    6 non-null      int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 420.0+ bytes

# %%
#　データフレームの統計量を表示
df.describe()
# Out:
#              age  new_col
# count   4.000000      6.0
# mean   38.750000      1.0
# std    14.361407      0.0
# min    30.000000      1.0
# 25%    30.000000      1.0
# 50%    32.500000      1.0
# 75%    41.250000      1.0
# max    60.000000      1.0

# %%
# 列情報
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'new_col'], dtype='object')

# %%
# 行情報
df.index
# Out:
# RangeIndex(start=1, stop=7, step=1)

# %%
# データフレームの型
df.dtypes
# Out:
# age          float64
# job           object
# marital       object
# education     object
# default       object
# new_col        int64
# dtype: object

# %%
# (行数, 列数)
df.shape
# Out:
# (6, 6)

# %%
# 行数
len(df)
# Out:
# 6

# %% [markdown]
# ### データの操作
# - コピー
# - 参照（スライシング）
# - 列・行の取得
# - シリーズ
# - 代入、削除、列・行の追加
# - 欠損処理
# - 重複処理
# - 集計処理
# - 列名とインデックス
# - 集約処理（groupby）
# - ピボットテーブル
# - 型の変更
# - ソート
# - データフレームの作成

# %% [markdown]
# #### コピー
#  - copy

# %%
base = df.copy()
base.head()
# Out:
#     age          job  marital  education default  new_col
# 1  30.0   unemployed  married    primary      no        1
# 2   NaN     services  married  secondary      no        1
# 3  35.0   management   single   tertiary      no        1
# 4  30.0   management  married   tertiary      no        1
# 5  60.0  blue-collar  married  secondary      no        1

# %% [markdown]
# #### セルの取得
# - loc
# - iloc

# %%
# loc[行名, 列名]
df.loc[0,"age"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     354                 try:
# --> 355                     return self._range.index(new_key)
#     356                 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-65b4048138e1> in <module>
#       1 # loc[行名, 列名]
# ----> 2 df.loc[0,"age"]
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1042     def _getitem_tuple(self, tup: Tuple):
#    1043         try:
# -> 1044             return self._getitem_lowerdim(tup)
#    1045         except IndexingError:
#    1046             pass
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     784                 # We don't need to check for tuples here because those are
#     785                 #  caught by the _is_nested_tuple_indexer check above.
# --> 786                 section = self._getitem_axis(key, axis=i)
#     787
#     788                 # We should never have a scalar section here, because
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3491             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3492         else:
# -> 3493             loc = self.index.get_loc(key)
#    3494
#    3495             if isinstance(loc, np.ndarray):
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     355                     return self._range.index(new_key)
#     356                 except ValueError as err:
# --> 357                     raise KeyError(key) from err
#     358             raise KeyError(key)
#     359         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 0

# %%
df.loc[8,"day"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     354                 try:
# --> 355                     return self._range.index(new_key)
#     356                 except ValueError as err:
#
# ValueError: 8 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-e6bb8f3a3c65> in <module>
# ----> 1 df.loc[8,"day"]
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1042     def _getitem_tuple(self, tup: Tuple):
#    1043         try:
# -> 1044             return self._getitem_lowerdim(tup)
#    1045         except IndexingError:
#    1046             pass
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     784                 # We don't need to check for tuples here because those are
#     785                 #  caught by the _is_nested_tuple_indexer check above.
# --> 786                 section = self._getitem_axis(key, axis=i)
#     787
#     788                 # We should never have a scalar section here, because
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3491             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3492         else:
# -> 3493             loc = self.index.get_loc(key)
#    3494
#    3495             if isinstance(loc, np.ndarray):
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     355                     return self._range.index(new_key)
#     356                 except ValueError as err:
# --> 357                     raise KeyError(key) from err
#     358             raise KeyError(key)
#     359         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 8

# %%
df.loc[[0,1], ["age", "job"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-b625f46df8f2> in <module>
# ----> 1 df.loc[[0,1], ["age", "job"]]
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1051         # ugly hack for GH #836
#    1052         if self._multi_take_opportunity(tup):
# -> 1053             return self._multi_take(tup)
#    1054
#    1055         return self._getitem_tuple_same_dim(tup)
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexing.py in _multi_take(self, tup)
#    1003         d = {
#    1004             axis: self._get_listlike_indexer(key, axis)
# -> 1005             for (key, axis) in zip(tup, self.obj._AXIS_ORDERS)
#    1006         }
#    1007         return self.obj._reindex_with_indexers(d, copy=True, allow_dups=True)
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexing.py in <dictcomp>(.0)
#    1003         d = {
#    1004             axis: self._get_listlike_indexer(key, axis)
# -> 1005             for (key, axis) in zip(tup, self.obj._AXIS_ORDERS)
#    1006         }
#    1007         return self.obj._reindex_with_indexers(d, copy=True, allow_dups=True)
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314                 with option_context("display.max_seq_items", 10, "display.width", 80):
#    1315                     raise KeyError(
# -> 1316                         "Passing list-likes to .loc or [] with any missing labels "
#    1317                         "is no longer supported. "
#    1318                         f"The following labels were missing: {not_found}. "
#
# KeyError: "Passing list-likes to .loc or [] with any missing labels is no longer supported. The following labels were missing: Int64Index([0], dtype='int64'). See https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike"

# %%
df.loc[[0,3], ["day","duration"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-2abe97f4a2ae> in <module>
# ----> 1 df.loc[[0,3], ["day","duration"]]
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1051         # ugly hack for GH #836
#    1052         if self._multi_take_opportunity(tup):
# -> 1053             return self._multi_take(tup)
#    1054
#    1055         return self._getitem_tuple_same_dim(tup)
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexing.py in _multi_take(self, tup)
#    1003         d = {
#    1004             axis: self._get_listlike_indexer(key, axis)
# -> 1005             for (key, axis) in zip(tup, self.obj._AXIS_ORDERS)
#    1006         }
#    1007         return self.obj._reindex_with_indexers(d, copy=True, allow_dups=True)
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexing.py in <dictcomp>(.0)
#    1003         d = {
#    1004             axis: self._get_listlike_indexer(key, axis)
# -> 1005             for (key, axis) in zip(tup, self.obj._AXIS_ORDERS)
#    1006         }
#    1007         return self.obj._reindex_with_indexers(d, copy=True, allow_dups=True)
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314                 with option_context("display.max_seq_items", 10, "display.width", 80):
#    1315                     raise KeyError(
# -> 1316                         "Passing list-likes to .loc or [] with any missing labels "
#    1317                         "is no longer supported. "
#    1318                         f"The following labels were missing: {not_found}. "
#
# KeyError: "Passing list-likes to .loc or [] with any missing labels is no longer supported. The following labels were missing: Int64Index([0], dtype='int64'). See https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike"

# %%
df.loc[0:1, "age":"job"]
# Out:
#     age         job
# 1  30.0  unemployed

# %%
# iloc[行インデックス, 列インデックス]
df.iloc[0,0]
# Out:
# 30.0

# %%
df.iloc[[0,1],[0,1]]
# Out:
#     age         job
# 1  30.0  unemployed
# 2   NaN    services

# %%
df.iloc[[0,3],[0,3]]
# Out:
#     age education
# 1  30.0   primary
# 4  30.0  tertiary

# %%
df.iloc[0:1,0:1]
# Out:
#     age
# 1  30.0

# %%
df.iloc[0:3,0:3]
# Out:
#     age         job  marital
# 1  30.0  unemployed  married
# 2   NaN    services  married
# 3  35.0  management   single

# %%
df = df.iloc[:5, :5]
df
# Out:
#     age          job  marital  education default
# 1  30.0   unemployed  married    primary      no
# 2   NaN     services  married  secondary      no
# 3  35.0   management   single   tertiary      no
# 4  30.0   management  married   tertiary      no
# 5  60.0  blue-collar  married  secondary      no

# %%
df = df.iloc[:5, :5]
df
# Out:
#     age          job  marital  education default
# 1  30.0   unemployed  married    primary      no
# 2   NaN     services  married  secondary      no
# 3  35.0   management   single   tertiary      no
# 4  30.0   management  married   tertiary      no
# 5  60.0  blue-collar  married  secondary      no

# %% [markdown]
# #### 列の取得

# %%
df.loc[:, ["age","job"]]
# Out:
#     age          job
# 1  30.0   unemployed
# 2   NaN     services
# 3  35.0   management
# 4  30.0   management
# 5  60.0  blue-collar

# %%
df[["age","job"]]
# Out:
#     age          job
# 1  30.0   unemployed
# 2   NaN     services
# 3  35.0   management
# 4  30.0   management
# 5  60.0  blue-collar

# %%
df[["age"]]
# Out:
#     age
# 1  30.0
# 2   NaN
# 3  35.0
# 4  30.0
# 5  60.0

# %%
type(df[["age","job"]])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df["age"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### Series

# %%
ser = df["age"]

# %%
ser[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     354                 try:
# --> 355                     return self._range.index(new_key)
#     356                 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-1430aae6f4a5> in <module>
# ----> 1 ser[0]
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     988
#     989         # Similar to Index.get_value, but we do not fall back to positional
# --> 990         loc = self.index.get_loc(label)
#     991         return self.index._get_values_for_loc(self, loc, label)
#     992
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     355                     return self._range.index(new_key)
#     356                 except ValueError as err:
# --> 357                     raise KeyError(key) from err
#     358             raise KeyError(key)
#     359         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 0

# %%
ser[0:2]
# Out:
# 1    30.0
# 2     NaN
# Name: age, dtype: float64

# %%
ser.index
# Out:
# RangeIndex(start=1, stop=6, step=1)

# %% [markdown]
# #### 行の取得

# %%
df
# Out:
#     age          job  marital  education default
# 1  30.0   unemployed  married    primary      no
# 2   NaN     services  married  secondary      no
# 3  35.0   management   single   tertiary      no
# 4  30.0   management  married   tertiary      no
# 5  60.0  blue-collar  married  secondary      no

# %%
ser = df["age"]
target = ser > 30
target
# Out:
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# Name: age, dtype: bool

# %%
ser
# Out:
# 1    30.0
# 2     NaN
# 3    35.0
# 4    30.0
# 5    60.0
# Name: age, dtype: float64

# %%
# True/Falseのリスト形式のものを入れるとTrueの行を取得
df[target]
# Out:
#     age          job  marital  education default
# 3  35.0   management   single   tertiary      no
# 5  60.0  blue-collar  married  secondary      no

# %%
df[df["age"] > 30]
# Out:
#     age          job  marital  education default
# 3  35.0   management   single   tertiary      no
# 5  60.0  blue-collar  married  secondary      no

# %% [markdown]
# #### 代入

# %%
df
# Out:
#     age          job  marital  education default
# 1  30.0   unemployed  married    primary      no
# 2   NaN     services  married  secondary      no
# 3  35.0   management   single   tertiary      no
# 4  30.0   management  married   tertiary      no
# 5  60.0  blue-collar  married  secondary      no

# %%
# セルを指定して代入
df.loc[4, "age"] = 60
df
# Out:
#     age          job  marital  education default
# 1  30.0   unemployed  married    primary      no
# 2   NaN     services  married  secondary      no
# 3  35.0   management   single   tertiary      no
# 4  60.0   management  married   tertiary      no
# 5  60.0  blue-collar  married  secondary      no

# %%
# 列を指定して代入
yes_list = ["yes"] * 5
print(yes_list)
df["default"] = yes_list
df
# Out:
# ['yes', 'yes', 'yes', 'yes', 'yes']
#     age          job  marital  education default
# 1  30.0   unemployed  married    primary     yes
# 2   NaN     services  married  secondary     yes
# 3  35.0   management   single   tertiary     yes
# 4  60.0   management  married   tertiary     yes
# 5  60.0  blue-collar  married  secondary     yes

# %%
df["default"] = "no"
df
# Out:
#     age          job  marital  education default
# 1  30.0   unemployed  married    primary      no
# 2   NaN     services  married  secondary      no
# 3  35.0   management   single   tertiary      no
# 4  60.0   management  married   tertiary      no
# 5  60.0  blue-collar  married  secondary      no

# %% [markdown]
# #### 削除
# - drop
# - del

# %%
# 列を削除
df.drop(columns="job")
# Out:
#     age  marital  education default
# 1  30.0  married    primary      no
# 2   NaN  married  secondary      no
# 3  35.0   single   tertiary      no
# 4  60.0  married   tertiary      no
# 5  60.0  married  secondary      no

# %%
df.drop("job", axis=1)
# Out:
#     age  marital  education default
# 1  30.0  married    primary      no
# 2   NaN  married  secondary      no
# 3  35.0   single   tertiary      no
# 4  60.0  married   tertiary      no
# 5  60.0  married  secondary      no

# %%
del df["job"]
df
# Out:
#     age  marital  education default
# 1  30.0  married    primary      no
# 2   NaN  married  secondary      no
# 3  35.0   single   tertiary      no
# 4  60.0  married   tertiary      no
# 5  60.0  married  secondary      no

# %%
# 行の削除
df.drop(2)
# Out:
#     age  marital  education default
# 1  30.0  married    primary      no
# 3  35.0   single   tertiary      no
# 4  60.0  married   tertiary      no
# 5  60.0  married  secondary      no

# %% [markdown]
# #### 追加

# %%
#　列の追加  
df["new_col"] = 1
df
# Out:
#     age  marital  education default  new_col
# 1  30.0  married    primary      no        1
# 2   NaN  married  secondary      no        1
# 3  35.0   single   tertiary      no        1
# 4  60.0  married   tertiary      no        1
# 5  60.0  married  secondary      no        1

# %%
# 行の追加  
df.loc[5, :] = [40.0, "single", "secondary", "yes", 2]
df
# Out:
#     age  marital  education default  new_col
# 1  30.0  married    primary      no        1
# 2   NaN  married  secondary      no        1
# 3  35.0   single   tertiary      no        1
# 4  60.0  married   tertiary      no        1
# 5  40.0   single  secondary     yes        2

# %% [markdown]
# #### 欠損処理
# - isnull
# - dropna
# - ffill
# - bfill
# - interpolate
# - fillna

# %%
df
# Out:
#     age  marital  education default  new_col
# 1  30.0  married    primary      no        1
# 2   NaN  married  secondary      no        1
# 3  35.0   single   tertiary      no        1
# 4  60.0  married   tertiary      no        1
# 5  40.0   single  secondary     yes        2

# %%
# 欠損セルの確認
df.isnull()
# Out:
#      age  marital  education  default  new_col
# 1  False    False      False    False    False
# 2   True    False      False    False    False
# 3  False    False      False    False    False
# 4  False    False      False    False    False
# 5  False    False      False    False    False

# %%
# 欠損列の確認
df.isnull().any()
# Out:
# age           True
# marital      False
# education    False
# default      False
# new_col      False
# dtype: bool

# %%
# 欠損行の確認
df.isnull().any(axis=1)
# Out:
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
# 欠損行の抽出  
df[df.isnull().any(axis=1)]
# Out:
#    age  marital  education default  new_col
# 2  NaN  married  secondary      no        1

# %%
# 欠損行の削除
df.dropna()
# Out:
#     age  marital  education default  new_col
# 1  30.0  married    primary      no        1
# 3  35.0   single   tertiary      no        1
# 4  60.0  married   tertiary      no        1
# 5  40.0   single  secondary     yes        2

# %%
# 欠損列の削除
df.dropna(axis=1)
# Out:
#    marital  education default  new_col
# 1  married    primary      no        1
# 2  married  secondary      no        1
# 3   single   tertiary      no        1
# 4  married   tertiary      no        1
# 5   single  secondary     yes        2

# %%
# 欠損を埋める(フォワードフィル)
df.ffill()
# Out:
#     age  marital  education default  new_col
# 1  30.0  married    primary      no        1
# 2  30.0  married  secondary      no        1
# 3  35.0   single   tertiary      no        1
# 4  60.0  married   tertiary      no        1
# 5  40.0   single  secondary     yes        2

# %%
# 欠損を埋める(バックフィル)
df.bfill()
# Out:
#     age  marital  education default  new_col
# 1  30.0  married    primary      no        1
# 2  35.0  married  secondary      no        1
# 3  35.0   single   tertiary      no        1
# 4  60.0  married   tertiary      no        1
# 5  40.0   single  secondary     yes        2

# %%
# 欠損を埋める(線形補完)
df.interpolate()
# Out:
#     age  marital  education default  new_col
# 1  30.0  married    primary      no        1
# 2  32.5  married  secondary      no        1
# 3  35.0   single   tertiary      no        1
# 4  60.0  married   tertiary      no        1
# 5  40.0   single  secondary     yes        2

# %%
# 欠損を埋める(任意の値)
df.fillna(100)
# Out:
#      age  marital  education default  new_col
# 1   30.0  married    primary      no        1
# 2  100.0  married  secondary      no        1
# 3   35.0   single   tertiary      no        1
# 4   60.0  married   tertiary      no        1
# 5   40.0   single  secondary     yes        2

# %%
df.fillna(df["age"].mean())
# Out:
#      age  marital  education default  new_col
# 1  30.00  married    primary      no        1
# 2  41.25  married  secondary      no        1
# 3  35.00   single   tertiary      no        1
# 4  60.00  married   tertiary      no        1
# 5  40.00   single  secondary     yes        2

# %% [markdown]
# #### 重複処理
# - duplicated
# - drop_duplicates

# %%
#　重複行の確認
df.duplicated()
# Out:
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
df[["default","new_col"]].duplicated()
# Out:
# 1    False
# 2     True
# 3     True
# 4     True
# 5    False
# dtype: bool

# %%
# 重複削除
df[["default","new_col"]].drop_duplicates()
# Out:
#   default  new_col
# 1      no        1
# 5     yes        2

# %%
df.drop_duplicates(["default","new_col"])
# Out:
#     age  marital  education default  new_col
# 1  30.0  married    primary      no        1
# 5  40.0   single  secondary     yes        2

# %% [markdown]
# #### 集計処理

# %%
df
# Out:
#     age  marital  education default  new_col
# 1  30.0  married    primary      no        1
# 2   NaN  married  secondary      no        1
# 3  35.0   single   tertiary      no        1
# 4  60.0  married   tertiary      no        1
# 5  40.0   single  secondary     yes        2

# %%
df.sum()
# Out:
# age                                                165
# marital              marriedmarriedsinglemarriedsingle
# education    primarysecondarytertiarytertiarysecondary
# default                                    nonononoyes
# new_col                                              6
# dtype: object

# %%
df.sum(axis=1)
# Out:
# 1    31.0
# 2     1.0
# 3    36.0
# 4    61.0
# 5    42.0
# dtype: float64

# %%
df.max()
# Out:
# age                60
# marital        single
# education    tertiary
# default           yes
# new_col             2
# dtype: object

# %%
#　平均値
df.mean()
# Out:
# age        41.25
# new_col     1.20
# dtype: float64

# %%
# 列の合計
df["new_col"].sum()
# Out:
# 6

# %% [markdown]
# #### 列名とインデックス
# - columns, index
# - reset_index

# %%
df
# Out:
#     age  marital  education default  new_col
# 1  30.0  married    primary      no        1
# 2   NaN  married  secondary      no        1
# 3  35.0   single   tertiary      no        1
# 4  60.0  married   tertiary      no        1
# 5  40.0   single  secondary     yes        2

# %%
# 列名の変更
print(df.columns)
df.columns = ["age", "marital", "education", "default", "new_col2"]
df
# Out:
# Index(['age', 'marital', 'education', 'default', 'new_col'], dtype='object')
#     age  marital  education default  new_col2
# 1  30.0  married    primary      no         1
# 2   NaN  married  secondary      no         1
# 3  35.0   single   tertiary      no         1
# 4  60.0  married   tertiary      no         1
# 5  40.0   single  secondary     yes         2

# %%
df = df.rename(columns={"new_col2":"new_col3"})
df
# Out:
#     age  marital  education default  new_col3
# 1  30.0  married    primary      no         1
# 2   NaN  married  secondary      no         1
# 3  35.0   single   tertiary      no         1
# 4  60.0  married   tertiary      no         1
# 5  40.0   single  secondary     yes         2

# %%
# インデックスの変更　　
df.index = range(1,7)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-a638fdd4b790> in <module>
#       1 # インデックスの変更
# ----> 2 df.index = range(1,7)
#       3 df
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5152         try:
#    5153             object.__getattribute__(self, name)
# -> 5154             return object.__setattr__(self, name, value)
#    5155         except AttributeError:
#    5156             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     562     def _set_axis(self, axis: int, labels: Index) -> None:
#     563         labels = ensure_index(labels)
# --> 564         self._mgr.set_axis(axis, labels)
#     565         self._clear_item_cache()
#     566
#
# ~\.conda\envs\openCV\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     225         if new_len != old_len:
#     226             raise ValueError(
# --> 227                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     228                 f"values have {new_len} elements"
#     229             )
#
# ValueError: Length mismatch: Expected axis has 5 elements, new values have 6 elements

# %%
# インデックスの初期化  
df.reset_index()
# Out:
#    index   age  marital  education default  new_col3
# 0      1  30.0  married    primary      no         1
# 1      2   NaN  married  secondary      no         1
# 2      3  35.0   single   tertiary      no         1
# 3      4  60.0  married   tertiary      no         1
# 4      5  40.0   single  secondary     yes         2

# %%
df.reset_index(drop=True)
# Out:
#     age  marital  education default  new_col3
# 0  30.0  married    primary      no         1
# 1   NaN  married  secondary      no         1
# 2  35.0   single   tertiary      no         1
# 3  60.0  married   tertiary      no         1
# 4  40.0   single  secondary     yes         2

# %% [markdown]
# #### 集約処理
# - groupby

# %%
df
# Out:
#     age  marital  education default  new_col3
# 1  30.0  married    primary      no         1
# 2   NaN  married  secondary      no         1
# 3  35.0   single   tertiary      no         1
# 4  60.0  married   tertiary      no         1
# 5  40.0   single  secondary     yes         2

# %%
df.groupby("marital")

# %%
df.groupby("marital").sum()
# Out:
#           age  new_col3
# marital
# married  90.0         3
# single   75.0         3

# %%
df.groupby("marital").sum().reset_index()
# Out:
#    marital   age  new_col3
# 0  married  90.0         3
# 1   single  75.0         3

# %%
df.groupby(["marital", "education"]).max().reset_index()
# Out:
#    marital  education   age default  new_col3
# 0  married    primary  30.0      no         1
# 1  married  secondary   NaN      no         1
# 2  married   tertiary  60.0      no         1
# 3   single  secondary  40.0     yes         2
# 4   single   tertiary  35.0      no         1

# %% [markdown]
# #### ピボットテーブル
# - pivot_table

# %%
df.pivot_table(values="age", index=["marital", "education"], columns="default")
# Out:
# default              no   yes
# marital education
# married primary    30.0   NaN
#         secondary  60.0   NaN
#         tertiary   30.0   NaN
# single  secondary   NaN  40.0
#         tertiary   35.0   NaN

# %% [markdown]
# #### その他の処理
# - inplace
# - astype
# - sort_values
# - pd.DataFrame

# %%
# inplaceで破壊的に置き換え
df = df.rename(columns={"new_col3":"new_col4"})
df
# Out:
#     age  marital  education default  new_col4
# 1  30.0  married    primary      no         1
# 2   NaN  married  secondary      no         1
# 3  35.0   single   tertiary      no         1
# 4  60.0  married   tertiary      no         1
# 5  40.0   single  secondary     yes         2

# %%
df.rename(columns={"new_col4":"new_col3"}, inplace=True)
df
# Out:
#     age  marital  education default  new_col3
# 1  30.0  married    primary      no         1
# 2   NaN  married  secondary      no         1
# 3  35.0   single   tertiary      no         1
# 4  60.0  married   tertiary      no         1
# 5  40.0   single  secondary     yes         2

# %%
# 型の変更
df["new_col3"] = df["new_col3"].astype(int)
df
# Out:
#     age  marital  education default  new_col3
# 1  30.0  married    primary      no         1
# 2   NaN  married  secondary      no         1
# 3  35.0   single   tertiary      no         1
# 4  30.0  married   tertiary      no         1
# 5  60.0  married  secondary      no         1
# 6  40.0   single  secondary     yes         2

# %%
# ソート　　
df.sort_values("age")
# Out:
#     age  marital  education default  new_col3
# 1  30.0  married    primary      no         1
# 4  30.0  married   tertiary      no         1
# 3  35.0   single   tertiary      no         1
# 6  40.0   single  secondary     yes         2
# 5  60.0  married  secondary      no         1
# 2   NaN  married  secondary      no         1

# %%
#逆順
df.sort_values("age", ascending=False)
# Out:
#     age  marital  education default  new_col3
# 4  60.0  married   tertiary      no         1
# 5  40.0   single  secondary     yes         2
# 3  35.0   single   tertiary      no         1
# 1  30.0  married    primary      no         1
# 2   NaN  married  secondary      no         1

# %%
df.sort_values(["new_col3", "age"], ascending=[True, False])
# Out:
#     age  marital  education default  new_col3
# 5  60.0  married  secondary      no         1
# 3  35.0   single   tertiary      no         1
# 1  30.0  married    primary      no         1
# 4  30.0  married   tertiary      no         1
# 2   NaN  married  secondary      no         1
# 6  40.0   single  secondary     yes         2

# %%
# データフレームの作成
new_df = pd.DataFrame(data=[[1,2],[3,4]], columns=["a", "b"])
new_df
# Out:
#    a  b
# 0  1  2
# 1  3  4

# %% [markdown]
# ### 複数データフレームの処理
# - merge
# - append
# - concat

# %% [markdown]
# #### データフレームの結合

# %%
df
# Out:
#     age  marital  education default  new_col3
# 1  30.0  married    primary      no         1
# 2   NaN  married  secondary      no         1
# 3  35.0   single   tertiary      no         1
# 4  60.0  married   tertiary      no         1
# 5  40.0   single  secondary     yes         2

# %%
df2 = base.copy()
df2 = df2.loc[45:50, ["age","education"]]
df2.loc[45, "age"] = 30.0
df2["new_col4"] = 4
df2
# Out:
#      age education  new_col4
# 45  30.0       NaN         4

# %%
# on句でキーを指定して結合（inner join）
df.merge(df2, on=["age", "education"])
# Out:
# Empty DataFrame
# Columns: [age, marital, education, default, new_col3, new_col4]
# Index: []

# %%
# on句でキーを指定して結合（left outer join）
df.merge(df2, on=["age", "education"], how="left")
# Out:
#     age  marital  education default  new_col3  new_col4
# 0  30.0  married    primary      no         1       NaN
# 1   NaN  married  secondary      no         1       NaN
# 2  35.0   single   tertiary      no         1       NaN
# 3  60.0  married   tertiary      no         1       NaN
# 4  40.0   single  secondary     yes         2       NaN

# %%
# 新しいデータフレームを行を追加する形で結合  
df3 = base.copy()
df3 = df3.loc[50:55, ["age","marital","education","default"]]
df3["new_col3"] = 3
df3
# Out:
# Empty DataFrame
# Columns: [age, marital, education, default, new_col3]
# Index: []

# %%
df
# Out:
#     age  marital  education default  new_col3
# 1  30.0  married    primary      no         1
# 2   NaN  married  secondary      no         1
# 3  35.0   single   tertiary      no         1
# 4  60.0  married   tertiary      no         1
# 5  40.0   single  secondary     yes         2

# %%
# appendによる追加
df.append(df3)
# Out:
#     age  marital  education default  new_col3
# 1  30.0  married    primary      no         1
# 2   NaN  married  secondary      no         1
# 3  35.0   single   tertiary      no         1
# 4  60.0  married   tertiary      no         1
# 5  40.0   single  secondary     yes         2

# %%
df.append(df3, ignore_index=True)
# Out:
#     age  marital  education default  new_col3
# 0  30.0  married    primary      no         1
# 1   NaN  married  secondary      no         1
# 2  35.0   single   tertiary      no         1
# 3  60.0  married   tertiary      no         1
# 4  40.0   single  secondary     yes         2

# %%
# concatによる追加  
pd.concat([df, df3])
# Out:
#     age  marital  education default  new_col3
# 1  30.0  married    primary      no         1
# 2   NaN  married  secondary      no         1
# 3  35.0   single   tertiary      no         1
# 4  60.0  married   tertiary      no         1
# 5  40.0   single  secondary     yes         2

# %% [markdown]
# ###  one-hotエンコーディング
# - get_dummies

# %%
df
# Out:
#     age  marital  education default  new_col3
# 1  30.0  married    primary      no         1
# 2   NaN  married  secondary      no         1
# 3  35.0   single   tertiary      no         1
# 4  30.0  married   tertiary      no         1
# 5  60.0  married  secondary      no         1
# 6  40.0   single  secondary     yes         2

# %%
pd.get_dummies(df["marital"])
# Out:
#    married  single
# 1        1       0
# 2        1       0
# 3        0       1
# 4        1       0
# 5        1       0
# 6        0       1

# %%
pd.get_dummies(df)
# Out:
#     age  new_col3  marital_married  marital_single  education_primary  \
# 1  30.0         1                1               0                  1
# 2   NaN         1                1               0                  0
# 3  35.0         1                0               1                  0
# 4  30.0         1                1               0                  0
# 5  60.0         1                1               0                  0
# 6  40.0         2                0               1                  0
#
#    education_secondary  education_tertiary  default_no  default_yes
# 1                    0                   0           1            0
# 2                    1                   0           1            0
# 3                    0                   1           1            0
# 4                    0                   1           1            0
# 5                    1                   0           1            0
# 6                    1                   0           0            1
